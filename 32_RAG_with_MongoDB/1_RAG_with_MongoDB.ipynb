# %% [markdown]
# # <h1 align="center"><font color="red">The Art of Chunking: Boosting AI Performance in RAG Architectures</font></h1>

# %% [markdown]
# <font color="yellow">Senior Data Scientist.: Dr. Eddy Giusepe Chirinos Isidro</font>

# %% [markdown]
# Links de estudo:
#
# * [Medium: Han HELOIR, Ph.D. ☕️](https://towardsdatascience.com/the-art-of-chunking-boosting-ai-performance-in-rag-architectures-acdbdb8bdc2b)
#
# * [Apoorva Joshi: How to Choose the Right Chunking Strategy for Your LLM Application](https://www.mongodb.com/developer/products/atlas/choosing-chunking-strategy-rag/)

# %% [markdown]
# # <font color="gree">RAG</font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <font color="gree">Chunking</font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <font color="gree">Fixed Character Sizes</font>

# %% [markdown]
# ![image.png](attachment:image.png)
